# %% [markdown]
# # What is Git?
#
# - Free and open-source distributed version control system
# - Can handle small to large applications and projects
# - Allows team members to use the same files by distributed branches/environments
