# %% [markdown]
# ### SQL BASIC QUERIES INTRODUCTION

# %% [markdown]
# ### INSERTING DATABASE TABLE (TODOS)
#
# `INSERT INTO todos (title, description, priority, complete) VALUES ('Go to store', 'To pick up eggs', 4, False);`

# %% [markdown]
# `INSERT INTO todos (title, description, priority, complete) VALUES ('Haircut', 'Need to get length 1mm', 3, False);`

# %% [markdown]
# `INSERT INTO todos (title, description, priority, complete) VALUES ('Feed dog', 'Make sure to use new food brand', 5, False);`

# %% [markdown]
# `INSERT INTO todos (title, description, priority, complete) VALUES ('Water plant', 'Inside and Outside plants', 4, False);`

# %% [markdown]
# `INSERT INTO todos (title, description, priority, complete) VALUES ('Shower', 'You have not showered in days', 5, False);`

# %% [markdown]
# ### SELECT SQL QUERIES

# %% [markdown]
# `SELECT * FROM todos;`

# %% [markdown]
# `SELECT title FROM todos;`

# %% [markdown]
# `SELECT description FROM todos;`

# %% [markdown]
# `SELECT title, description FROM todos;`

# %% [markdown]
# `SELECT title, description, priority FROM todos;`

# %% [markdown]
# ### WHERE SQL QUERIES

# %% [markdown]
# `SELECT * FROM todos WHERE priority = 5;`

# %% [markdown]
# `SELECT * FROM todos WHERE title="Feed dog";`

# %% [markdown]
# `SELECT * FROM todos WHERE id=2;`

# %% [markdown]
# ### UPDATE SQL QUERIES

# %% [markdown]
# `UPDATE todos SET complete=True WHERE id=5;`

# %% [markdown]
# `UPDATE todos SET complete=True WHERE title="Learn something new;`

# %% [markdown]
# ### DELETE SQL QUERIES

# %% [markdown]
# `DELETE FROM todos WHERE id=5;`

# %% [markdown]
# `DELETE FROM todos WHERE complete=0;`

# %% [markdown]
# ### WHAT IS A FOREIGN KEY?

# %% [markdown]
# - A foreign key (FK) is a column within a relational database that provides a link between two separate tables.
#
# - A foreign key references a primary key of another table.
#
# - Most relational databases need foreign keys to able to link tables together to present data
